# %%
x = 5
print(x)
# Out:
# 5

# %%
x = 1000
print(x)
# Out:
# 1000

# %%
savings = 1000
factor = 1.1
result = savings * factor ** 15
print(result)
# Out:
# 4177.248169415656

# %%
desc = 'Data Science'
profitable = True

# %%
a = 10 
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(savings))

print(type(factor))

print(type(desc))

print(type(profitable))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
savings = 1000
factor = 1.10
desc = "Data Science"

year1 = savings * factor

print(type(year1))

doubledesc = desc * 2

print(doubledesc)
# Out:
# <class 'float'>
# Data ScienceData Science
