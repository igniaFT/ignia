# %%
n = int(input("Nhập một số nguyên dương n: "))
tong_cac_so = 0
for so in range(n + 1):
    tong_cac_so += so
print(f"Tổng các số từ 0 đến {n} là: {tong_cac_so}")
# Out:
# Nhập một số nguyên dương n:  4
# Tổng các số từ 0 đến 4 là: 10
