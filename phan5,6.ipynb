# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "livingroom", 20.0, "bedroom", 10.75, "bathroom", 9.50]
areas[-1] = 10.25
areas[4] = 'chillzone'
print(areas)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'chillzone', 20.0, 'bedroom', 10.75, 'bathroom', 10.25]

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "livingroom", 20.0, "bedroom", 10.75, "bathroom", 9.50]
areas_1 = areas + ["poolhouse", 24.5]
areas_2 = list(areas_1)
areas_2.extend(["garage", 15.45])
print(areas_1)
print(areas_2)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'livingroom', 20.0, 'bedroom', 10.75, 'bathroom', 9.5, 'poolhouse', 24.5]
# ['hallway', 11.25, 'kitchen', 18.0, 'livingroom', 20.0, 'bedroom', 10.75, 'bathroom', 9.5, 'poolhouse', 24.5, 'garage', 15.45]

# %%
areas = ['hallway', 11.25, 'kitchen', 18.0, 'livingroom', 20.0, 'bedroom', 10.75, 'bathroom', 9.5, 'poolhouse', 24.5, 'garage', 15.45]
del(areas[-3])
del(areas[-4])
print(areas)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'livingroom', 20.0, 'bedroom', 10.75, 'bathroom', 'poolhouse', 'garage', 15.45]

# %%
areas = [11.25, 18.0, 20.0, 10.75, 9.50]
areas_copy = list(areas)
areas_copy[0] = 5.0
print(areas)
# Out:
# [11.25, 18.0, 20.0, 10.75, 9.5]

# %%
var1 = [1, 2, 3, 4]
var2 = True
print(type(var1))
print(len(var1))
out2 = int(var2)
# Out:
# <class 'list'>
# 4

# %%
first = [11.25, 18.0, 20.0]
second = [10.75, 9.50]


full = first + second


full_sorted = sorted(full, reverse=True)


print(full_sorted)
# Out:
# [20.0, 18.0, 11.25, 10.75, 9.5]
